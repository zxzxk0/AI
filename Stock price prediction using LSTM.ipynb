# %%
# Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
google_stock_data = pd.read_csv('/content/drive/MyDrive/machine learning projects/training set/Google Stock Prediction/GOOG.csv')
google_stock_data.head()
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0

# %%
google_stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
google_stock_data = google_stock_data[['date','open','close']] # Extracting required columns
google_stock_data['date'] = pd.to_datetime(google_stock_data['date'].apply(lambda x: x.split()[0])) # Selecting only date
google_stock_data.set_index('date',drop=True,inplace=True) # Setting date column as index
google_stock_data.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71

# %%
fg, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(google_stock_data['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(google_stock_data['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fg.show()

# %% [markdown]
# Data Pre-Processing

# %%
from sklearn.preprocessing import MinMaxScaler
MMS = MinMaxScaler()
google_stock_data[google_stock_data.columns] = MMS.fit_transform(google_stock_data)

# %%
google_stock_data.shape
# Out:
# (1258, 2)

# %%
training_size = round(len(google_stock_data) * 0.80) # Selecting 80 % for training and 20 % for testing
training_size
# Out:
# 1006

# %%
train_data = google_stock_data[:training_size]
test_data  = google_stock_data[training_size:]

train_data.shape, test_data.shape
# Out:
# ((1006, 2), (252, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)

# %%
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((956, 50, 2), (956, 2), (202, 50, 2), (202, 2))

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1)) 
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30,902
# Trainable params: 30,902
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(train_seq, train_label, epochs=80,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/80
# 30/30 [==============================] - 14s 164ms/step - loss: 0.0072 - mean_absolute_error: 0.0577 - val_loss: 0.0134 - val_mean_absolute_error: 0.0975
# Epoch 2/80
# 30/30 [==============================] - 2s 64ms/step - loss: 7.5445e-04 - mean_absolute_error: 0.0212 - val_loss: 0.0059 - val_mean_absolute_error: 0.0634
# Epoch 3/80
# 30/30 [==============================] - 2s 58ms/step - loss: 5.3570e-04 - mean_absolute_error: 0.0164 - val_loss: 0.0053 - val_mean_absolute_error: 0.0608
# Epoch 4/80
# 30/30 [==============================] - 2s 58ms/step - loss: 5.1993e-04 - mean_absolute_error: 0.0163 - val_loss: 0.0048 - val_mean_absolute_error: 0.0568
# Epoch 5/80
# 30/30 [==============================] - 2s 61ms/step - loss: 4.9625e-04 - mean_absolute_error: 0.0159 - val_loss: 0.0036 - val_mean_absolute_error: 0.0484
# Epoch 6/80
# 30/30 [==============================] - 3s 92ms/step - loss: 4.8558e-04 - mean_absolute_error: 0.0156 - val_loss: 0.0044 - val_mean_absolute_error: 0.0547
# Epoch 7/80
# 30/30 [==============================] - 3s 85ms/step - loss: 4.4575e-04 - mean_absolute_error: 0.0149 - val_loss: 0.0044 - val_mean_absolute_error: 0.0543
# Epoch 8/80
# 30/30 [==============================] - 3s 88ms/step - loss: 4.3765e-04 - mean_absolute_error: 0.0151 - val_loss: 0.0063 - val_mean_absolute_error: 0.0681
# Epoch 9/80
# 30/30 [==============================] - 3s 96ms/step - loss: 4.1563e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0032 - val_mean_absolute_error: 0.0455
# Epoch 10/80
# 30/30 [==============================] - 3s 99ms/step - loss: 4.5174e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0021 - val_mean_absolute_error: 0.0354
# Epoch 11/80
# 30/30 [==============================] - 3s 90ms/step - loss: 4.0132e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0070 - val_mean_absolute_error: 0.0723
# Epoch 12/80
# 30/30 [==============================] - 3s 99ms/step - loss: 3.8957e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0024 - val_mean_absolute_error: 0.0383
# Epoch 13/80
# 30/30 [==============================] - 2s 79ms/step - loss: 3.7579e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0045 - val_mean_absolute_error: 0.0559
# Epoch 14/80
# 30/30 [==============================] - 3s 92ms/step - loss: 3.8141e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0029 - val_mean_absolute_error: 0.0415
# Epoch 15/80
# 30/30 [==============================] - 2s 73ms/step - loss: 3.7692e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0046 - val_mean_absolute_error: 0.0560
# Epoch 16/80
# 30/30 [==============================] - 2s 56ms/step - loss: 3.3061e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0036 - val_mean_absolute_error: 0.0482
# Epoch 17/80
# 30/30 [==============================] - 2s 59ms/step - loss: 3.6211e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0071 - val_mean_absolute_error: 0.0717
# Epoch 18/80
# 30/30 [==============================] - 2s 83ms/step - loss: 3.2642e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0034 - val_mean_absolute_error: 0.0455
# Epoch 19/80
# 30/30 [==============================] - 3s 84ms/step - loss: 3.4846e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0034 - val_mean_absolute_error: 0.0457
# Epoch 20/80
# 30/30 [==============================] - 2s 81ms/step - loss: 3.2433e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0048 - val_mean_absolute_error: 0.0561
# Epoch 21/80
# 30/30 [==============================] - 3s 95ms/step - loss: 3.1625e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0080 - val_mean_absolute_error: 0.0762
# Epoch 22/80
# 30/30 [==============================] - 3s 95ms/step - loss: 3.1732e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0058 - val_mean_absolute_error: 0.0631
# Epoch 23/80
# 30/30 [==============================] - 3s 92ms/step - loss: 3.0470e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0055 - val_mean_absolute_error: 0.0606
# Epoch 24/80
# 30/30 [==============================] - 3s 89ms/step - loss: 3.1260e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0068 - val_mean_absolute_error: 0.0692
# Epoch 25/80
# 30/30 [==============================] - 3s 86ms/step - loss: 3.0325e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0045 - val_mean_absolute_error: 0.0538
# Epoch 26/80
# 30/30 [==============================] - 3s 90ms/step - loss: 2.8702e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0068 - val_mean_absolute_error: 0.0687
# Epoch 27/80
# 30/30 [==============================] - 2s 64ms/step - loss: 2.7554e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0031 - val_mean_absolute_error: 0.0432
# Epoch 28/80
# 30/30 [==============================] - 2s 58ms/step - loss: 2.7358e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0052 - val_mean_absolute_error: 0.0586
# Epoch 29/80
# 30/30 [==============================] - 2s 57ms/step - loss: 2.7274e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0047 - val_mean_absolute_error: 0.0546
# Epoch 30/80
# 30/30 [==============================] - 2s 56ms/step - loss: 2.7367e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0044 - val_mean_absolute_error: 0.0525
# Epoch 31/80
# 30/30 [==============================] - 2s 57ms/step - loss: 2.7254e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0075 - val_mean_absolute_error: 0.0728
# Epoch 32/80
# 30/30 [==============================] - 2s 58ms/step - loss: 2.6754e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0056 - val_mean_absolute_error: 0.0616
# Epoch 33/80
# 30/30 [==============================] - 2s 58ms/step - loss: 2.5781e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0016 - val_mean_absolute_error: 0.0300
# Epoch 34/80
# 30/30 [==============================] - 2s 60ms/step - loss: 3.2970e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0031 - val_mean_absolute_error: 0.0433
# Epoch 35/80
# 30/30 [==============================] - 2s 62ms/step - loss: 2.7042e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0045 - val_mean_absolute_error: 0.0541
# Epoch 36/80
# 30/30 [==============================] - 2s 63ms/step - loss: 2.5639e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0033 - val_mean_absolute_error: 0.0452
# Epoch 37/80
# 30/30 [==============================] - 2s 61ms/step - loss: 2.4862e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0037 - val_mean_absolute_error: 0.0484
# Epoch 38/80
# 30/30 [==============================] - 2s 64ms/step - loss: 2.4136e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0045 - val_mean_absolute_error: 0.0545
# Epoch 39/80
# 30/30 [==============================] - 2s 61ms/step - loss: 2.2629e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0040 - val_mean_absolute_error: 0.0513
# Epoch 40/80
# 30/30 [==============================] - 2s 61ms/step - loss: 2.3827e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0032 - val_mean_absolute_error: 0.0447
# Epoch 41/80
# 30/30 [==============================] - 2s 59ms/step - loss: 2.7542e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0018 - val_mean_absolute_error: 0.0319
# Epoch 42/80
# 30/30 [==============================] - 2s 57ms/step - loss: 2.2954e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0033 - val_mean_absolute_error: 0.0451
# Epoch 43/80
# 30/30 [==============================] - 2s 56ms/step - loss: 2.4409e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0037 - val_mean_absolute_error: 0.0489
# Epoch 44/80
# 30/30 [==============================] - 2s 57ms/step - loss: 2.3649e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0072 - val_mean_absolute_error: 0.0734
# Epoch 45/80
# 30/30 [==============================] - 2s 56ms/step - loss: 2.4212e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0034 - val_mean_absolute_error: 0.0467
# Epoch 46/80
# 30/30 [==============================] - 2s 57ms/step - loss: 2.3104e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0063 - val_mean_absolute_error: 0.0684
# Epoch 47/80
# 30/30 [==============================] - 2s 55ms/step - loss: 2.4911e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0035 - val_mean_absolute_error: 0.0481
# Epoch 48/80
# 30/30 [==============================] - 2s 74ms/step - loss: 2.3851e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0036 - val_mean_absolute_error: 0.0487
# Epoch 49/80
# 30/30 [==============================] - 2s 57ms/step - loss: 2.2084e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0031 - val_mean_absolute_error: 0.0448
# Epoch 50/80
# 30/30 [==============================] - 2s 56ms/step - loss: 2.1401e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0027 - val_mean_absolute_error: 0.0413
# Epoch 51/80
# 30/30 [==============================] - 2s 60ms/step - loss: 2.0849e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0017 - val_mean_absolute_error: 0.0319
# Epoch 52/80
# 30/30 [==============================] - 2s 64ms/step - loss: 2.1210e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0035 - val_mean_absolute_error: 0.0487
# Epoch 53/80
# 30/30 [==============================] - 2s 62ms/step - loss: 2.0332e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0049 - val_mean_absolute_error: 0.0591
# Epoch 54/80
# 30/30 [==============================] - 2s 63ms/step - loss: 1.9890e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0022 - val_mean_absolute_error: 0.0368
# Epoch 55/80
# 30/30 [==============================] - 2s 62ms/step - loss: 2.1331e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0031 - val_mean_absolute_error: 0.0460
# Epoch 56/80
# 30/30 [==============================] - 2s 62ms/step - loss: 1.9510e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0029 - val_mean_absolute_error: 0.0446
# Epoch 57/80
# 30/30 [==============================] - 2s 59ms/step - loss: 2.2859e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0021 - val_mean_absolute_error: 0.0360
# Epoch 58/80
# 30/30 [==============================] - 2s 59ms/step - loss: 2.3678e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0016 - val_mean_absolute_error: 0.0311
# Epoch 59/80
# 30/30 [==============================] - 2s 58ms/step - loss: 2.0732e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0020 - val_mean_absolute_error: 0.0344
# Epoch 60/80
# 30/30 [==============================] - 2s 58ms/step - loss: 1.8798e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0039 - val_mean_absolute_error: 0.0512
# Epoch 61/80
# 30/30 [==============================] - 2s 58ms/step - loss: 1.8776e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0035 - val_mean_absolute_error: 0.0481
# Epoch 62/80
# 30/30 [==============================] - 2s 57ms/step - loss: 1.7507e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0024 - val_mean_absolute_error: 0.0378
# Epoch 63/80
# 30/30 [==============================] - 2s 58ms/step - loss: 1.8887e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0051 - val_mean_absolute_error: 0.0604
# Epoch 64/80
# 30/30 [==============================] - 2s 60ms/step - loss: 1.9072e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0021 - val_mean_absolute_error: 0.0361
# Epoch 65/80
# 30/30 [==============================] - 2s 58ms/step - loss: 1.7474e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0020 - val_mean_absolute_error: 0.0355
# Epoch 66/80
# 30/30 [==============================] - 2s 58ms/step - loss: 1.7345e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0022 - val_mean_absolute_error: 0.0369
# Epoch 67/80
# 30/30 [==============================] - 2s 58ms/step - loss: 1.7565e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0040 - val_mean_absolute_error: 0.0519
# Epoch 68/80
# 30/30 [==============================] - 2s 63ms/step - loss: 1.7460e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0037 - val_mean_absolute_error: 0.0502
# Epoch 69/80
# 30/30 [==============================] - 2s 63ms/step - loss: 1.7664e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0048 - val_mean_absolute_error: 0.0590
# Epoch 70/80
# 30/30 [==============================] - 2s 63ms/step - loss: 1.7704e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0015 - val_mean_absolute_error: 0.0292
# Epoch 71/80
# 30/30 [==============================] - 2s 63ms/step - loss: 1.7029e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0017 - val_mean_absolute_error: 0.0317
# Epoch 72/80
# 30/30 [==============================] - 2s 62ms/step - loss: 1.7120e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0015 - val_mean_absolute_error: 0.0296
# Epoch 73/80
# 30/30 [==============================] - 3s 111ms/step - loss: 1.5911e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0040 - val_mean_absolute_error: 0.0531
# Epoch 74/80
# 30/30 [==============================] - 3s 104ms/step - loss: 1.8129e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0019 - val_mean_absolute_error: 0.0338
# Epoch 75/80
# 30/30 [==============================] - 3s 117ms/step - loss: 1.5786e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0023 - val_mean_absolute_error: 0.0384
# Epoch 76/80
# 30/30 [==============================] - 2s 76ms/step - loss: 1.4929e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0023 - val_mean_absolute_error: 0.0386
# Epoch 77/80
# 30/30 [==============================] - 2s 57ms/step - loss: 1.6546e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0023 - val_mean_absolute_error: 0.0383
# Epoch 78/80
# 30/30 [==============================] - 2s 55ms/step - loss: 1.5510e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0057 - val_mean_absolute_error: 0.0656
# Epoch 79/80
# 30/30 [==============================] - 2s 58ms/step - loss: 1.7150e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0039 - val_mean_absolute_error: 0.0519
# Epoch 80/80
# 30/30 [==============================] - 2s 59ms/step - loss: 1.4648e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0033 - val_mean_absolute_error: 0.0474

# %%
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# array([[0.477562  , 0.47735834],
#        [0.48492175, 0.48452002],
#        [0.4893734 , 0.48871195],
#        [0.50107604, 0.5003899 ],
#        [0.51243615, 0.5117316 ]], dtype=float32)

# %%
test_inverse_predicted = MMS.inverse_transform(test_predicted) # Inversing scaling on predicted data
test_inverse_predicted[:5]
# Out:
# array([[1556.3618, 1552.9674],
#        [1570.0061, 1566.2404],
#        [1578.2592, 1574.0094],
#        [1599.955 , 1595.6526],
#        [1621.0156, 1616.6727]], dtype=float32)

# %% [markdown]
# Visualizing predicted and actual data

# %%
# Merging actual and predicted data for better visualization

gs_slic_data = pd.concat([google_stock_data.iloc[-202:].copy(),pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],index=google_stock_data.iloc[-202:].index)], axis=1)

# %%
gs_slic_data[['open','close']] = MMS.inverse_transform(gs_slic_data[['open','close']]) # Inverse scaling

# %%
gs_slic_data.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-08-24  1593.98  1588.20     1556.361816      1552.967407
# 2020-08-25  1582.07  1608.22     1570.006104      1566.240356
# 2020-08-26  1608.00  1652.38     1578.259155      1574.009399
# 2020-08-27  1653.68  1634.33     1599.954956      1595.652588
# 2020-08-28  1633.49  1644.41     1621.015625      1616.672729

# %%
gs_slic_data[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
gs_slic_data[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %% [markdown]
# Predicting upcoming 10 days

# %%
# Creating a dataframe and adding 10 days to existing index 

gs_slic_data = gs_slic_data.append(pd.DataFrame(columns=gs_slic_data.columns,index=pd.date_range(start=gs_slic_data.index[-1], periods=11, freq='D', closed='right')))

# %%
gs_slic_data['2021-06-09	':'2021-06-16']
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2324.185059      2286.044922
# 2021-06-10  2494.01  2521.60     2343.515381      2303.104736
# 2021-06-11  2524.92  2513.93     2353.938965      2310.177979
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=gs_slic_data.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)

# %%
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
fg,ax=plt.subplots(figsize=(10,5))
ax.plot(gs_slic_data.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fg.show()

# %%
fg,ax=plt.subplots(figsize=(10,5))
ax.plot(gs_slic_data.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fg.show()
