# %%
# Importing the required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns

# %%
# The function is defined with default parameters so that if you call it with just your data, it will construct a DataFrame with t-1 
# as X and t as y

def series_to_supervised(data, n_in = 1, n_out = 1, dropnan = True):
    n_vars = 1 if type(data) is list else data.shape[1]
    
    df = pd.DataFrame(data)
    cols, names = list(), list()
    
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
        
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
            
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
        
    return agg

# %%
df = pd.read_csv("/content/drive/MyDrive/machine learning projects/training set/Air Pollution Forecasting - LSTM Multivariate/LSTM-Multivariate_pollution.csv")

# %%
df
# Out:
#                       date  pollution  dew  temp   press wnd_dir  wnd_spd  \
# 0      2010-01-02 00:00:00      129.0  -16  -4.0  1020.0      SE     1.79
# 1      2010-01-02 01:00:00      148.0  -15  -4.0  1020.0      SE     2.68
# 2      2010-01-02 02:00:00      159.0  -11  -5.0  1021.0      SE     3.57
# 3      2010-01-02 03:00:00      181.0   -7  -5.0  1022.0      SE     5.36
# 4      2010-01-02 04:00:00      138.0   -7  -5.0  1022.0      SE     6.25
# ...                    ...        ...  ...   ...     ...     ...      ...
# 43795  2014-12-31 19:00:00        8.0  -23  -2.0  1034.0      NW   231.97
# 43796  2014-12-31 20:00:00       10.0  -22  -3.0  1034.0      NW   237.78
# 43797  2014-12-31 21:00:00       10.0  -22  -3.0  1034.0      NW   242.70
# 43798  2014-12-31 22:00:00        8.0  -22  -4.0  1034.0      NW   246.72
# 43799  2014-12-31 23:00:00       12.0  -21  -3.0  1034.0      NW   249.85
#
#        snow  rain
# 0         0     0
# 1         0     0
# 2         0     0
# 3         1     0
# 4         2     0
# ...     ...   ...
# 43795     0     0
# 43796     0     0
# 43797     0     0
# 43798     0     0
# 43799     0     0
#
# [43800 rows x 9 columns]

# %%
df["wnd_dir"].unique()
# Out:
# array(['SE', 'cv', 'NW', 'NE'], dtype=object)

# %%
# Encoding the string based data feature into integers

def func(s):
    if s == "SE":
        return 1
    elif s == "NE":
        return 2
    elif s == "NW":
        return 3
    else:
        return 4

df["wind_dir"] = df["wnd_dir"].apply(func)

# %%
del df["wnd_dir"]

# %%
df
# Out:
#                       date  pollution  dew  temp   press  wnd_spd  snow  rain  \
# 0      2010-01-02 00:00:00      129.0  -16  -4.0  1020.0     1.79     0     0
# 1      2010-01-02 01:00:00      148.0  -15  -4.0  1020.0     2.68     0     0
# 2      2010-01-02 02:00:00      159.0  -11  -5.0  1021.0     3.57     0     0
# 3      2010-01-02 03:00:00      181.0   -7  -5.0  1022.0     5.36     1     0
# 4      2010-01-02 04:00:00      138.0   -7  -5.0  1022.0     6.25     2     0
# ...                    ...        ...  ...   ...     ...      ...   ...   ...
# 43795  2014-12-31 19:00:00        8.0  -23  -2.0  1034.0   231.97     0     0
# 43796  2014-12-31 20:00:00       10.0  -22  -3.0  1034.0   237.78     0     0
# 43797  2014-12-31 21:00:00       10.0  -22  -3.0  1034.0   242.70     0     0
# 43798  2014-12-31 22:00:00        8.0  -22  -4.0  1034.0   246.72     0     0
# 43799  2014-12-31 23:00:00       12.0  -21  -3.0  1034.0   249.85     0     0
#
#        wind_dir
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ...         ...
# 43795         3
# 43796         3
# 43797         3
# 43798         3
# 43799         3
#
# [43800 rows x 9 columns]

# %%
values = df.values

# specify columns to plot
groups = [1, 2, 3, 5, 6]
i = 1

# plot each column
plt.figure(figsize=(20,14))
for group in groups:
    plt.subplot(len(groups), 1, i)
    plt.plot(values[:, group], c = "forestgreen")
    plt.title(df.columns[group], y=0.75, loc='right', fontsize = 15)
    i += 1
plt.show()

# %%
fig = plt.figure(figsize = (20,7))
plt.plot(df.pollution)
plt.title("Polution variation across the given no.of hours", fontsize = 15)
plt.show()

# %%
del df["date"]

# %%
from sklearn.metrics import mean_absolute_error , mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

# %%
# Scaling the entire dataset

dataset = df
values = dataset.values

values = values.astype('float32')

scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# %%
# converting the dataset as supervised learning

reframed = series_to_supervised(scaled, 1, 1)
print(reframed.shape)
# Out:
# (43799, 16)

# %%
print(reframed.head())

# Here, there are some unwanted data, which we don't want to predict, i.e here var2(t), var3(3), ....
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.129779   0.352941   0.245902   0.527273   0.002290   0.000000
# 2   0.148893   0.367647   0.245902   0.527273   0.003811   0.000000
# 3   0.159960   0.426471   0.229508   0.545454   0.005332   0.000000
# 4   0.182093   0.485294   0.229508   0.563637   0.008391   0.037037
# 5   0.138833   0.485294   0.229508   0.563637   0.009912   0.074074
#
#    var7(t-1)  var8(t-1)   var1(t)   var2(t)   var3(t)   var4(t)   var5(t)  \
# 1        0.0        0.0  0.148893  0.367647  0.245902  0.527273  0.003811
# 2        0.0        0.0  0.159960  0.426471  0.229508  0.545454  0.005332
# 3        0.0        0.0  0.182093  0.485294  0.229508  0.563637  0.008391
# 4        0.0        0.0  0.138833  0.485294  0.229508  0.563637  0.009912
# 5        0.0        0.0  0.109658  0.485294  0.213115  0.563637  0.011433
#
#     var6(t)  var7(t)  var8(t)
# 1  0.000000      0.0      0.0
# 2  0.000000      0.0      0.0
# 3  0.037037      0.0      0.0
# 4  0.074074      0.0      0.0
# 5  0.111111      0.0      0.0

# %%
reframed.columns
# Out:
# Index(['var1(t-1)', 'var2(t-1)', 'var3(t-1)', 'var4(t-1)', 'var5(t-1)',
#        'var6(t-1)', 'var7(t-1)', 'var8(t-1)', 'var1(t)', 'var2(t)', 'var3(t)',
#        'var4(t)', 'var5(t)', 'var6(t)', 'var7(t)', 'var8(t)'],
#       dtype='object')

# %%
# droping columns we don't want to predict

reframed.drop(reframed.columns[[9,10,11,12,13,14,15]], axis=1, inplace=True)
print(reframed.head())
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.129779   0.352941   0.245902   0.527273   0.002290   0.000000
# 2   0.148893   0.367647   0.245902   0.527273   0.003811   0.000000
# 3   0.159960   0.426471   0.229508   0.545454   0.005332   0.000000
# 4   0.182093   0.485294   0.229508   0.563637   0.008391   0.037037
# 5   0.138833   0.485294   0.229508   0.563637   0.009912   0.074074
#
#    var7(t-1)  var8(t-1)   var1(t)
# 1        0.0        0.0  0.148893
# 2        0.0        0.0  0.159960
# 3        0.0        0.0  0.182093
# 4        0.0        0.0  0.138833
# 5        0.0        0.0  0.109658

# %%
values = reframed.values

# We train the model on the 1st 3 years and then test on the last year (for now)
n_train_hours = 365 * 24 * 3

train = values[:n_train_hours, :]
test = values[n_train_hours:, :]

# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

# reshape input to be 3D :- (no.of samples, no.of timesteps, no.of features)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (26280, 1, 8) (26280,) (17519, 1, 8) (17519,)

# %%
train.shape, test.shape, values.shape
# Out:
# ((26280, 9), (17519, 9), (43799, 9))

# %%
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential

# %%
model = Sequential()
model.add(LSTM(64, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mse', optimizer='adam')

# fit network
history = model.fit(train_X, train_y, epochs=50, batch_size=72, validation_split=0.2, verbose=2, shuffle=False)
# Out:
# Epoch 1/50
# 292/292 - 4s - loss: 0.0045 - val_loss: 0.0040 - 4s/epoch - 14ms/step
# Epoch 2/50
# 292/292 - 1s - loss: 0.0017 - val_loss: 0.0019 - 788ms/epoch - 3ms/step
# Epoch 3/50
# 292/292 - 1s - loss: 0.0011 - val_loss: 0.0010 - 1s/epoch - 5ms/step
# Epoch 4/50
# 292/292 - 1s - loss: 9.2528e-04 - val_loss: 7.7335e-04 - 1s/epoch - 5ms/step
# Epoch 5/50
# 292/292 - 2s - loss: 8.7201e-04 - val_loss: 6.8504e-04 - 2s/epoch - 5ms/step
# Epoch 6/50
# 292/292 - 2s - loss: 8.5376e-04 - val_loss: 6.5075e-04 - 2s/epoch - 5ms/step
# Epoch 7/50
# 292/292 - 1s - loss: 8.4687e-04 - val_loss: 6.3264e-04 - 1s/epoch - 4ms/step
# Epoch 8/50
# 292/292 - 1s - loss: 8.4277e-04 - val_loss: 6.1673e-04 - 1s/epoch - 4ms/step
# Epoch 9/50
# 292/292 - 1s - loss: 8.4016e-04 - val_loss: 6.0291e-04 - 1s/epoch - 4ms/step
# Epoch 10/50
# 292/292 - 2s - loss: 8.3932e-04 - val_loss: 5.9283e-04 - 2s/epoch - 5ms/step
# Epoch 11/50
# 292/292 - 1s - loss: 8.3949e-04 - val_loss: 5.8503e-04 - 1s/epoch - 4ms/step
# Epoch 12/50
# 292/292 - 1s - loss: 8.3968e-04 - val_loss: 5.7851e-04 - 1s/epoch - 4ms/step
# Epoch 13/50
# 292/292 - 1s - loss: 8.3959e-04 - val_loss: 5.7337e-04 - 1s/epoch - 3ms/step
# Epoch 14/50
# 292/292 - 1s - loss: 8.3924e-04 - val_loss: 5.6963e-04 - 942ms/epoch - 3ms/step
# Epoch 15/50
# 292/292 - 1s - loss: 8.3868e-04 - val_loss: 5.6704e-04 - 922ms/epoch - 3ms/step
# Epoch 16/50
# 292/292 - 1s - loss: 8.3793e-04 - val_loss: 5.6533e-04 - 913ms/epoch - 3ms/step
# Epoch 17/50
# 292/292 - 1s - loss: 8.3704e-04 - val_loss: 5.6426e-04 - 891ms/epoch - 3ms/step
# Epoch 18/50
# 292/292 - 1s - loss: 8.3607e-04 - val_loss: 5.6365e-04 - 926ms/epoch - 3ms/step
# Epoch 19/50
# 292/292 - 1s - loss: 8.3506e-04 - val_loss: 5.6337e-04 - 859ms/epoch - 3ms/step
# Epoch 20/50
# 292/292 - 1s - loss: 8.3404e-04 - val_loss: 5.6333e-04 - 956ms/epoch - 3ms/step
# Epoch 21/50
# 292/292 - 1s - loss: 8.3304e-04 - val_loss: 5.6346e-04 - 1s/epoch - 4ms/step
# Epoch 22/50
# 292/292 - 1s - loss: 8.3208e-04 - val_loss: 5.6370e-04 - 956ms/epoch - 3ms/step
# Epoch 23/50
# 292/292 - 1s - loss: 8.3115e-04 - val_loss: 5.6401e-04 - 987ms/epoch - 3ms/step
# Epoch 24/50
# 292/292 - 1s - loss: 8.3026e-04 - val_loss: 5.6437e-04 - 804ms/epoch - 3ms/step
# Epoch 25/50
# 292/292 - 1s - loss: 8.2941e-04 - val_loss: 5.6475e-04 - 1s/epoch - 4ms/step
# Epoch 26/50
# 292/292 - 1s - loss: 8.2859e-04 - val_loss: 5.6514e-04 - 1s/epoch - 4ms/step
# Epoch 27/50
# 292/292 - 1s - loss: 8.2781e-04 - val_loss: 5.6552e-04 - 1s/epoch - 4ms/step
# Epoch 28/50
# 292/292 - 1s - loss: 8.2706e-04 - val_loss: 5.6588e-04 - 1s/epoch - 5ms/step
# Epoch 29/50
# 292/292 - 1s - loss: 8.2633e-04 - val_loss: 5.6627e-04 - 1s/epoch - 4ms/step
# Epoch 30/50
# 292/292 - 1s - loss: 8.2563e-04 - val_loss: 5.6667e-04 - 1s/epoch - 5ms/step
# Epoch 31/50
# 292/292 - 1s - loss: 8.2496e-04 - val_loss: 5.6705e-04 - 1s/epoch - 5ms/step
# Epoch 32/50
# 292/292 - 1s - loss: 8.2431e-04 - val_loss: 5.6739e-04 - 1s/epoch - 4ms/step
# Epoch 33/50
# 292/292 - 1s - loss: 8.2367e-04 - val_loss: 5.6771e-04 - 1s/epoch - 5ms/step
# Epoch 34/50
# 292/292 - 1s - loss: 8.2305e-04 - val_loss: 5.6799e-04 - 1s/epoch - 5ms/step
# Epoch 35/50
# 292/292 - 1s - loss: 8.2244e-04 - val_loss: 5.6825e-04 - 1s/epoch - 4ms/step
# Epoch 36/50
# 292/292 - 1s - loss: 8.2185e-04 - val_loss: 5.6848e-04 - 971ms/epoch - 3ms/step
# Epoch 37/50
# 292/292 - 1s - loss: 8.2127e-04 - val_loss: 5.6870e-04 - 1s/epoch - 5ms/step
# Epoch 38/50
# 292/292 - 1s - loss: 8.2070e-04 - val_loss: 5.6891e-04 - 1s/epoch - 4ms/step
# Epoch 39/50
# 292/292 - 1s - loss: 8.2015e-04 - val_loss: 5.6915e-04 - 1s/epoch - 5ms/step
# Epoch 40/50
# 292/292 - 1s - loss: 8.1961e-04 - val_loss: 5.6936e-04 - 1s/epoch - 5ms/step
# Epoch 41/50
# 292/292 - 1s - loss: 8.1905e-04 - val_loss: 5.6960e-04 - 1s/epoch - 4ms/step
# Epoch 42/50
# 292/292 - 1s - loss: 8.1854e-04 - val_loss: 5.6981e-04 - 1s/epoch - 4ms/step
# Epoch 43/50
# 292/292 - 1s - loss: 8.1802e-04 - val_loss: 5.7000e-04 - 1s/epoch - 3ms/step
# Epoch 44/50
# 292/292 - 1s - loss: 8.1752e-04 - val_loss: 5.7016e-04 - 1s/epoch - 3ms/step
# Epoch 45/50
# 292/292 - 1s - loss: 8.1702e-04 - val_loss: 5.7031e-04 - 992ms/epoch - 3ms/step
# Epoch 46/50
# 292/292 - 1s - loss: 8.1653e-04 - val_loss: 5.7053e-04 - 1s/epoch - 4ms/step
# Epoch 47/50
# 292/292 - 1s - loss: 8.1605e-04 - val_loss: 5.7073e-04 - 1s/epoch - 5ms/step
# Epoch 48/50
# 292/292 - 2s - loss: 8.1558e-04 - val_loss: 5.7090e-04 - 2s/epoch - 5ms/step
# Epoch 49/50
# 292/292 - 1s - loss: 8.1512e-04 - val_loss: 5.7106e-04 - 1s/epoch - 5ms/step
# Epoch 50/50
# 292/292 - 1s - loss: 8.1467e-04 - val_loss: 5.7121e-04 - 966ms/epoch - 3ms/step

# %%
plt.figure(figsize=(15,6))
plt.plot(history.history['loss'], label='train', linewidth = 2.5)
plt.plot(history.history['val_loss'], label='test',  linewidth = 2.5)
plt.legend()
plt.show()

# %%
test_X.shape
# Out:
# (17519, 1, 8)

# %%
testPredict = model.predict(test_X)
print(testPredict.shape)
testPredict = testPredict.ravel()

print(testPredict.shape)
# Out:
# (17519, 1)
# (17519,)

# %%
test.shape
# Out:
# (17519, 9)

# %%
print(test), print(test.shape)
# Out:
# [[0.03521127 0.44117647 0.22950819 ... 0.         0.6666666  0.03118712]
#  [0.03118712 0.4264706  0.1967213  ... 0.         0.6666666  0.03219316]
#  [0.03219316 0.4264706  0.1967213  ... 0.         0.6666666  0.02112676]
#  ...
#  [0.01006036 0.2647059  0.26229507 ... 0.         0.6666666  0.01006036]
#  [0.01006036 0.2647059  0.26229507 ... 0.         0.6666666  0.00804829]
#  [0.00804829 0.2647059  0.24590163 ... 0.         0.6666666  0.01207243]]
# (17519, 9)
# (None, None)

# %%
y_test_true = test[:,8]

# %%
poll = np.array(df["pollution"])

meanop = poll.mean()
stdop = poll.std()

y_test_true = y_test_true*stdop + meanop
testPredict = testPredict*stdop + meanop

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(15,6))
plt.xlim([1000,1250])
plt.ylabel("ppm")
plt.xlabel("hrs")
plt.plot(y_test_true, c = "g", alpha = 0.90, linewidth = 2.5)
plt.plot(testPredict, c = "b", alpha = 0.75)
plt.title("Testing(Validation) data")
plt.show()

# testTrue = scaler.inverse_transform([testY]).ravel()

# %%
rmse = np.sqrt(mean_squared_error(y_test_true, testPredict))
print("Test(Validation) RMSE ="  ,rmse)

# As we see the,  RMSE for testing data is low, and visually as well, from the above plots, we can see that the basic model is able to
# predict the future values of pollution (in ppm) pretty well
# Out:
# Test(Validation) RMSE = 2.583132

# %%
model2 = Sequential()
model2.add(LSTM(256, input_shape=(train_X.shape[1], train_X.shape[2])))
model2.add(Dense(64))
model2.add(Dropout(0.25))
model2.add(BatchNormalization())
model2.add(Dense(1))

model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 256)               271360
#
#  dense_1 (Dense)             (None, 64)                16448
#
#  dropout (Dropout)           (None, 64)                0
#
#  batch_normalization (BatchN  (None, 64)               256
#  ormalization)
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 288,129
# Trainable params: 288,001
# Non-trainable params: 128
# _________________________________________________________________

# %%
model2.compile(loss='mse', optimizer='adam')

hist2 = model2.fit(train_X, train_y, epochs=50, batch_size=128, validation_data=(test_X, test_y))
# Out:
# Epoch 1/50
# 206/206 [==============================] - 5s 16ms/step - loss: 0.0100 - val_loss: 0.0080
# Epoch 2/50
# 206/206 [==============================] - 3s 13ms/step - loss: 0.0015 - val_loss: 0.0058
# Epoch 3/50
# 206/206 [==============================] - 3s 13ms/step - loss: 0.0015 - val_loss: 0.0031
# Epoch 4/50
# 206/206 [==============================] - 3s 13ms/step - loss: 0.0014 - val_loss: 0.0036
# Epoch 5/50
# 206/206 [==============================] - 4s 19ms/step - loss: 0.0015 - val_loss: 8.3632e-04
# Epoch 6/50
# 206/206 [==============================] - 5s 25ms/step - loss: 0.0013 - val_loss: 0.0024
# Epoch 7/50
# 206/206 [==============================] - 5s 26ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 8/50
# 206/206 [==============================] - 5s 23ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 9/50
# 206/206 [==============================] - 5s 25ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 10/50
# 206/206 [==============================] - 4s 21ms/step - loss: 0.0011 - val_loss: 7.9943e-04
# Epoch 11/50
# 206/206 [==============================] - 3s 14ms/step - loss: 0.0011 - val_loss: 7.3614e-04
# Epoch 12/50
# 206/206 [==============================] - 3s 14ms/step - loss: 0.0010 - val_loss: 7.9781e-04
# Epoch 13/50
# 206/206 [==============================] - 3s 14ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 14/50
# 206/206 [==============================] - 4s 21ms/step - loss: 0.0010 - val_loss: 7.8067e-04
# Epoch 15/50
# 206/206 [==============================] - 6s 27ms/step - loss: 9.9314e-04 - val_loss: 8.5429e-04
# Epoch 16/50
# 206/206 [==============================] - 5s 25ms/step - loss: 9.8544e-04 - val_loss: 7.5771e-04
# Epoch 17/50
# 206/206 [==============================] - 5s 25ms/step - loss: 9.7072e-04 - val_loss: 7.5836e-04
# Epoch 18/50
# 206/206 [==============================] - 3s 16ms/step - loss: 9.4814e-04 - val_loss: 8.3149e-04
# Epoch 19/50
# 206/206 [==============================] - 4s 19ms/step - loss: 9.5949e-04 - val_loss: 7.6309e-04
# Epoch 20/50
# 206/206 [==============================] - 4s 22ms/step - loss: 9.4185e-04 - val_loss: 7.3469e-04
# Epoch 21/50
# 206/206 [==============================] - 5s 22ms/step - loss: 8.9631e-04 - val_loss: 9.6133e-04
# Epoch 22/50
# 206/206 [==============================] - 4s 17ms/step - loss: 9.1524e-04 - val_loss: 7.8273e-04
# Epoch 23/50
# 206/206 [==============================] - 4s 21ms/step - loss: 9.1309e-04 - val_loss: 7.8536e-04
# Epoch 24/50
# 206/206 [==============================] - 4s 21ms/step - loss: 9.0888e-04 - val_loss: 0.0014
# Epoch 25/50
# 206/206 [==============================] - 4s 21ms/step - loss: 9.2387e-04 - val_loss: 7.3197e-04
# Epoch 26/50
# 206/206 [==============================] - 5s 23ms/step - loss: 9.1762e-04 - val_loss: 7.1527e-04
# Epoch 27/50
# 206/206 [==============================] - 5s 22ms/step - loss: 9.1961e-04 - val_loss: 7.5319e-04
# Epoch 28/50
# 206/206 [==============================] - 4s 20ms/step - loss: 9.2585e-04 - val_loss: 8.9798e-04
# Epoch 29/50
# 206/206 [==============================] - 5s 25ms/step - loss: 9.4021e-04 - val_loss: 7.4796e-04
# Epoch 30/50
# 206/206 [==============================] - 4s 22ms/step - loss: 9.1159e-04 - val_loss: 7.2247e-04
# Epoch 31/50
# 206/206 [==============================] - 5s 25ms/step - loss: 9.0394e-04 - val_loss: 7.6275e-04
# Epoch 32/50
# 206/206 [==============================] - 3s 15ms/step - loss: 9.4959e-04 - val_loss: 7.4035e-04
# Epoch 33/50
# 206/206 [==============================] - 4s 18ms/step - loss: 8.8516e-04 - val_loss: 8.2578e-04
# Epoch 34/50
# 206/206 [==============================] - 5s 23ms/step - loss: 8.9315e-04 - val_loss: 0.0010
# Epoch 35/50
# 206/206 [==============================] - 4s 20ms/step - loss: 8.9573e-04 - val_loss: 7.7973e-04
# Epoch 36/50
# 206/206 [==============================] - 4s 21ms/step - loss: 9.0238e-04 - val_loss: 8.1703e-04
# Epoch 37/50
# 206/206 [==============================] - 4s 20ms/step - loss: 9.3255e-04 - val_loss: 8.1283e-04
# Epoch 38/50
# 206/206 [==============================] - 4s 22ms/step - loss: 9.3916e-04 - val_loss: 7.3158e-04
# Epoch 39/50
# 206/206 [==============================] - 5s 22ms/step - loss: 9.2604e-04 - val_loss: 7.8949e-04
# Epoch 40/50
# 206/206 [==============================] - 4s 19ms/step - loss: 9.3330e-04 - val_loss: 7.6520e-04
# Epoch 41/50
# 206/206 [==============================] - 4s 21ms/step - loss: 9.0215e-04 - val_loss: 8.4546e-04
# Epoch 42/50
# 206/206 [==============================] - 3s 14ms/step - loss: 9.1868e-04 - val_loss: 8.0023e-04
# Epoch 43/50
# 206/206 [==============================] - 3s 14ms/step - loss: 9.0364e-04 - val_loss: 8.7922e-04
# Epoch 44/50
# 206/206 [==============================] - 6s 28ms/step - loss: 9.1672e-04 - val_loss: 9.7250e-04
# Epoch 45/50
# 206/206 [==============================] - 5s 25ms/step - loss: 9.2292e-04 - val_loss: 7.0623e-04
# Epoch 46/50
# 206/206 [==============================] - 6s 27ms/step - loss: 8.9722e-04 - val_loss: 0.0011
# Epoch 47/50
# 206/206 [==============================] - 5s 26ms/step - loss: 9.1822e-04 - val_loss: 9.1387e-04
# Epoch 48/50
# 206/206 [==============================] - 5s 24ms/step - loss: 9.2698e-04 - val_loss: 7.2863e-04
# Epoch 49/50
# 206/206 [==============================] - 3s 15ms/step - loss: 9.0044e-04 - val_loss: 7.3996e-04
# Epoch 50/50
# 206/206 [==============================] - 3s 14ms/step - loss: 9.0501e-04 - val_loss: 7.7936e-04

# %%
plt.figure(figsize=(15,6))
plt.plot(hist2.history['loss'], label='train', linewidth = 2.5)
plt.plot(hist2.history['val_loss'], label='test',  linewidth = 2.5)
plt.legend()
plt.show()

# %%
y_test_true = test[:,8]

# %%
testPredict2 = model2.predict(test_X)
testPredict2 = testPredict2.ravel()

# Inverse scaling the output, for better visual interpretation 

poll = np.array(df["pollution"])
meanop = poll.mean()
stdop = poll.std()

print(meanop, stdop)

y_test_true = y_test_true*stdop + meanop
testPredict2 = testPredict2*stdop + meanop
# Out:
# 94.01351598173515 92.25122315439845

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(15,6))
plt.xlim([1000,1250])
plt.ylabel("ppm")
plt.xlabel("hrs")
plt.plot(y_test_true, c = "g", alpha = 0.90, linewidth = 2.5)
plt.plot(testPredict2, c = "darkblue", alpha = 0.75)
plt.title("Testing(Validation) data")
plt.show()

# %%
rmse = np.sqrt(mean_squared_error(y_test_true, testPredict2))
print("Test(Validation) RMSE ="  ,rmse)
# Out:
# Test(Validation) RMSE = 2.5753777

# %%
values.shape
# Out:
# (43799, 9)

# %%
values
# Out:
# array([[0.12977867, 0.35294122, 0.24590163, ..., 0.        , 0.        ,
#         0.14889336],
#        [0.14889336, 0.36764708, 0.24590163, ..., 0.        , 0.        ,
#         0.15995975],
#        [0.15995975, 0.4264706 , 0.22950819, ..., 0.        , 0.        ,
#         0.18209255],
#        ...,
#        [0.01006036, 0.2647059 , 0.26229507, ..., 0.        , 0.6666666 ,
#         0.01006036],
#        [0.01006036, 0.2647059 , 0.26229507, ..., 0.        , 0.6666666 ,
#         0.00804829],
#        [0.00804829, 0.2647059 , 0.24590163, ..., 0.        , 0.6666666 ,
#         0.01207243]], dtype=float32)

# %%
train_x, train_y = values[:, :-1], values[:, -1]
print(train_x.shape, train_y.shape)
# Out:
# (43799, 8) (43799,)

# %%
train_x = train_x.reshape((train_x.shape[0], 1, train_x.shape[1]))

# %%
model3 = Sequential()
model3.add(LSTM(256, input_shape=(train_x.shape[1], train_x.shape[2])))
model3.add(Dense(32))
model3.add(Dropout(0.25))
model3.add(BatchNormalization())
model3.add(Dense(1))

model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 256)               271360
#
#  dense_3 (Dense)             (None, 32)                8224
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  batch_normalization_1 (Batc  (None, 32)               128
#  hNormalization)
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 279,745
# Trainable params: 279,681
# Non-trainable params: 64
# _________________________________________________________________

# %%
model3.compile(loss='mse', optimizer='adam')

hist3 = model3.fit(train_x, train_y, epochs=50, batch_size=256, validation_split=0.2)
# Out:
# Epoch 1/50
# 137/137 [==============================] - 5s 22ms/step - loss: 0.0099 - val_loss: 0.0078
# Epoch 2/50
# 137/137 [==============================] - 3s 19ms/step - loss: 0.0013 - val_loss: 0.0069
# Epoch 3/50
# 137/137 [==============================] - 3s 19ms/step - loss: 0.0012 - val_loss: 0.0054
# Epoch 4/50
# 137/137 [==============================] - 3s 19ms/step - loss: 0.0013 - val_loss: 0.0033
# Epoch 5/50
# 137/137 [==============================] - 2s 18ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 6/50
# 137/137 [==============================] - 3s 18ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 7/50
# 137/137 [==============================] - 2s 18ms/step - loss: 0.0013 - val_loss: 0.0043
# Epoch 8/50
# 137/137 [==============================] - 3s 19ms/step - loss: 0.0012 - val_loss: 9.5563e-04
# Epoch 9/50
# 137/137 [==============================] - 3s 19ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 10/50
# 137/137 [==============================] - 2s 18ms/step - loss: 0.0012 - val_loss: 7.1249e-04
# Epoch 11/50
# 137/137 [==============================] - 3s 18ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 12/50
# 137/137 [==============================] - 2s 18ms/step - loss: 0.0012 - val_loss: 8.0187e-04
# Epoch 13/50
# 137/137 [==============================] - 3s 18ms/step - loss: 0.0011 - val_loss: 7.0056e-04
# Epoch 14/50
# 137/137 [==============================] - 3s 18ms/step - loss: 0.0011 - val_loss: 7.9708e-04
# Epoch 15/50
# 137/137 [==============================] - 3s 23ms/step - loss: 0.0011 - val_loss: 9.5960e-04
# Epoch 16/50
# 137/137 [==============================] - 3s 18ms/step - loss: 0.0011 - val_loss: 6.3456e-04
# Epoch 17/50
# 137/137 [==============================] - 3s 18ms/step - loss: 0.0011 - val_loss: 8.6012e-04
# Epoch 18/50
# 137/137 [==============================] - 3s 19ms/step - loss: 0.0010 - val_loss: 7.4298e-04
# Epoch 19/50
# 137/137 [==============================] - 3s 19ms/step - loss: 0.0010 - val_loss: 6.2464e-04
# Epoch 20/50
# 137/137 [==============================] - 3s 19ms/step - loss: 9.8705e-04 - val_loss: 7.1983e-04
# Epoch 21/50
# 137/137 [==============================] - 3s 19ms/step - loss: 9.7546e-04 - val_loss: 7.7482e-04
# Epoch 22/50
# 137/137 [==============================] - 3s 18ms/step - loss: 9.8721e-04 - val_loss: 6.0059e-04
# Epoch 23/50
# 137/137 [==============================] - 3s 18ms/step - loss: 9.9682e-04 - val_loss: 6.1565e-04
# Epoch 24/50
# 137/137 [==============================] - 3s 18ms/step - loss: 9.7824e-04 - val_loss: 0.0012
# Epoch 25/50
# 137/137 [==============================] - 3s 18ms/step - loss: 9.9609e-04 - val_loss: 9.7849e-04
# Epoch 26/50
# 137/137 [==============================] - 3s 19ms/step - loss: 9.9308e-04 - val_loss: 6.4658e-04
# Epoch 27/50
# 137/137 [==============================] - 3s 19ms/step - loss: 9.5093e-04 - val_loss: 6.0081e-04
# Epoch 28/50
# 137/137 [==============================] - 3s 19ms/step - loss: 9.4215e-04 - val_loss: 6.1924e-04
# Epoch 29/50
# 137/137 [==============================] - 2s 18ms/step - loss: 9.3812e-04 - val_loss: 7.5907e-04
# Epoch 30/50
# 137/137 [==============================] - 3s 18ms/step - loss: 9.0769e-04 - val_loss: 6.7034e-04
# Epoch 31/50
# 137/137 [==============================] - 3s 18ms/step - loss: 9.4146e-04 - val_loss: 6.9736e-04
# Epoch 32/50
# 137/137 [==============================] - 2s 18ms/step - loss: 9.4571e-04 - val_loss: 6.1439e-04
# Epoch 33/50
# 137/137 [==============================] - 2s 18ms/step - loss: 9.3472e-04 - val_loss: 6.7289e-04
# Epoch 34/50
# 137/137 [==============================] - 3s 18ms/step - loss: 9.3888e-04 - val_loss: 6.0812e-04
# Epoch 35/50
# 137/137 [==============================] - 2s 18ms/step - loss: 9.1361e-04 - val_loss: 6.0055e-04
# Epoch 36/50
# 137/137 [==============================] - 2s 18ms/step - loss: 9.2231e-04 - val_loss: 6.0052e-04
# Epoch 37/50
# 137/137 [==============================] - 3s 18ms/step - loss: 9.2642e-04 - val_loss: 6.4105e-04
# Epoch 38/50
# 137/137 [==============================] - 2s 18ms/step - loss: 9.2539e-04 - val_loss: 6.5016e-04
# Epoch 39/50
# 137/137 [==============================] - 3s 18ms/step - loss: 9.1298e-04 - val_loss: 6.1521e-04
# Epoch 40/50
# 137/137 [==============================] - 3s 18ms/step - loss: 9.1714e-04 - val_loss: 6.7941e-04
# Epoch 41/50
# 137/137 [==============================] - 3s 18ms/step - loss: 9.3682e-04 - val_loss: 6.7746e-04
# Epoch 42/50
# 137/137 [==============================] - 3s 19ms/step - loss: 9.1632e-04 - val_loss: 8.0789e-04
# Epoch 43/50
# 137/137 [==============================] - 3s 18ms/step - loss: 9.0740e-04 - val_loss: 5.9528e-04
# Epoch 44/50
# 137/137 [==============================] - 3s 18ms/step - loss: 9.2260e-04 - val_loss: 6.3101e-04
# Epoch 45/50
# 137/137 [==============================] - 3s 19ms/step - loss: 9.2165e-04 - val_loss: 7.6126e-04
# Epoch 46/50
# 137/137 [==============================] - 3s 19ms/step - loss: 9.1688e-04 - val_loss: 6.3190e-04
# Epoch 47/50
# 137/137 [==============================] - 2s 18ms/step - loss: 9.3935e-04 - val_loss: 5.9553e-04
# Epoch 48/50
# 137/137 [==============================] - 2s 18ms/step - loss: 8.9890e-04 - val_loss: 6.2470e-04
# Epoch 49/50
# 137/137 [==============================] - 2s 18ms/step - loss: 9.1689e-04 - val_loss: 7.2370e-04
# Epoch 50/50
# 137/137 [==============================] - 2s 18ms/step - loss: 9.2191e-04 - val_loss: 5.9134e-04

# %%
plt.figure(figsize=(15,6))
plt.plot(hist3.history['loss'], label='train', linewidth = 2.5)
plt.plot(hist3.history['val_loss'], label='test',  linewidth = 2.5)
plt.legend()
plt.show()

# %%
y_train_true = values[:,8]

# %%
trainPredict3 = model3.predict(train_x)
trainPredict3 = trainPredict3.ravel()

# Inverse scaling the output, for better visual interpretation 

poll = np.array(df["pollution"])
meanop = poll.mean()
stdop = poll.std()

print(meanop, stdop)

y_train_true = y_train_true*stdop + meanop
trainPredict3 = trainPredict3*stdop + meanop
# Out:
# 94.01351598173515 92.25122315439845

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(18,5.5))
# plt.xlim([1000,1250])
plt.ylabel("ppm")
plt.xlabel("hrs")
plt.plot(y_train_true, c = "cyan", alpha = 0.90, linewidth = 2.5)
plt.plot(trainPredict3, c = "darkblue", alpha = 0.75)
plt.title("Training data")
plt.show()

# darkblue

# %%
rmse = np.sqrt(mean_squared_error(y_train_true, trainPredict3))
print("Training RMSE ="  ,rmse)
# Out:
# Training RMSE = 2.5025716

# %%
test_df = pd.read_csv("/content/drive/MyDrive/machine learning projects/training set/Air Pollution Forecasting - LSTM Multivariate/pollution_test_data1.csv")
test_df
# Out:
#      dew  temp  press wnd_dir  wnd_spd  snow  rain  pollution
# 0    -16     4   1027      SE     3.58     0     0        128
# 1    -17     5   1027      SE     7.60     0     0         77
# 2    -16     4   1027      SE     9.39     0     0         65
# 3    -16     1   1028      cv     0.89     0     0         79
# 4    -14     0   1028      NE     1.79     0     0         93
# ..   ...   ...    ...     ...      ...   ...   ...        ...
# 341  -23    -2   1034      NW   231.97     0     0          8
# 342  -22    -3   1034      NW   237.78     0     0         10
# 343  -22    -3   1034      NW   242.70     0     0         10
# 344  -22    -4   1034      NW   246.72     0     0          8
# 345  -21    -3   1034      NW   249.85     0     0         12
#
# [346 rows x 8 columns]

# %%
test_df["wind_dir"] = test_df["wnd_dir"].apply(func)
del test_df["wnd_dir"]

# %%
values_test = test_df.values
values_test = values_test.astype('float32')

# %%
scaler1 = MinMaxScaler()
scaled_test = scaler1.fit_transform(values_test)
reframed_test = series_to_supervised(scaled_test, 1, 1)

# %%
reframed_test
# Out:
#      var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1     0.523809       0.65   0.666668   0.007102        0.0        0.0
# 2     0.476190       0.70   0.666668   0.016223        0.0        0.0
# 3     0.523809       0.65   0.666668   0.020285        0.0        0.0
# 4     0.523809       0.50   0.708336   0.000998        0.0        0.0
# 5     0.619048       0.45   0.708336   0.003040        0.0        0.0
# ..         ...        ...        ...        ...        ...        ...
# 341   0.238095       0.35   0.916668   0.512128        0.0        0.0
# 342   0.190476       0.35   0.958336   0.525310        0.0        0.0
# 343   0.238095       0.30   0.958336   0.538493        0.0        0.0
# 344   0.238095       0.30   0.958336   0.549656        0.0        0.0
# 345   0.238095       0.25   0.958336   0.558778        0.0        0.0
#
#      var7(t-1)  var8(t-1)   var1(t)  var2(t)   var3(t)   var4(t)  var5(t)  \
# 1     0.288288   0.000000  0.476190     0.70  0.666668  0.016223      0.0
# 2     0.173423   0.000000  0.523809     0.65  0.666668  0.020285      0.0
# 3     0.146396   0.000000  0.523809     0.50  0.708336  0.000998      0.0
# 4     0.177928   1.000000  0.619048     0.45  0.708336  0.003040      0.0
# 5     0.209459   0.333333  0.571429     0.35  0.750000  0.007102      0.0
# ..         ...        ...       ...      ...       ...       ...      ...
# 341   0.022523   0.666667  0.190476     0.35  0.958336  0.525310      0.0
# 342   0.018018   0.666667  0.238095     0.30  0.958336  0.538493      0.0
# 343   0.022523   0.666667  0.238095     0.30  0.958336  0.549656      0.0
# 344   0.022523   0.666667  0.238095     0.25  0.958336  0.558778      0.0
# 345   0.018018   0.666667  0.285714     0.30  0.958336  0.565879      0.0
#
#      var6(t)   var7(t)   var8(t)
# 1        0.0  0.173423  0.000000
# 2        0.0  0.146396  0.000000
# 3        0.0  0.177928  1.000000
# 4        0.0  0.209459  0.333333
# 5        0.0  0.234234  0.333333
# ..       ...       ...       ...
# 341      0.0  0.018018  0.666667
# 342      0.0  0.022523  0.666667
# 343      0.0  0.022523  0.666667
# 344      0.0  0.018018  0.666667
# 345      0.0  0.027027  0.666667
#
# [345 rows x 16 columns]

# %%
reframed_test.drop(reframed_test.columns[[9,10,11,12,13,14,15]], axis=1, inplace=True)
print(reframed_test.head())
# Out:
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  var6(t-1)  \
# 1   0.523809       0.65   0.666668   0.007102        0.0        0.0
# 2   0.476190       0.70   0.666668   0.016223        0.0        0.0
# 3   0.523809       0.65   0.666668   0.020285        0.0        0.0
# 4   0.523809       0.50   0.708336   0.000998        0.0        0.0
# 5   0.619048       0.45   0.708336   0.003040        0.0        0.0
#
#    var7(t-1)  var8(t-1)   var1(t)
# 1   0.288288   0.000000  0.476190
# 2   0.173423   0.000000  0.523809
# 3   0.146396   0.000000  0.523809
# 4   0.177928   1.000000  0.619048
# 5   0.209459   0.333333  0.571429

# %%
values_test1 = reframed_test.values

test_x, test_y = values_test1[:, :-1], values_test1[:, -1]

test_x = test_x.reshape((test_x.shape[0], 1, test_x.shape[1]))

# %%
test_x.shape, test_y.shape
# Out:
# ((345, 1, 8), (345,))

# %%
testPredict3 = model3.predict(test_x)
testPredict3 = testPredict3.ravel()
poll = np.array(df["pollution"])
meanop = poll.mean()
stdop = poll.std()

print(meanop, stdop)

# Inverse scaling the output, for better visual interpretation 
test_y = test_y*stdop + meanop
testPredict3 = testPredict3*stdop + meanop
# Out:
# 94.01351598173515 92.25122315439845

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(18,5.5))
plt.ylabel("ppm")
plt.xlabel("hrs")
plt.plot(test_y, c = "lightgreen", alpha = 0.90, linewidth = 2.5)
plt.plot(testPredict3, c = "darkblue", alpha = 0.75)
plt.title("Testing data")
plt.show()
# darkblue

# %%
rmse = np.sqrt(mean_squared_error(test_y, testPredict3))
print("Test RMSE ="  ,rmse)
# Out:
# Test RMSE = 10.3742895
