# %%
import torch
import torch.nn as nn

from torchvision import datasets
import torchvision.transforms as transforms
from torchvision.utils import save_image

# %%
latent_dim = 100


# 생성자(Generator) 클래스 정의
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()

        # 하나의 블록(block) 정의
        def block(input_dim, output_dim, normalize=True):
            layers = [nn.Linear(input_dim, output_dim)]
            if normalize:
                # 배치 정규화(batch normalization) 수행(차원 동일)
                layers.append(nn.BatchNorm1d(output_dim, 0.8))
            layers.append(nn.LeakyReLU(0.2, inplace=True))
            return layers

        # 생성자 모델은 연속적인 여러 개의 블록을 가짐
        self.model = nn.Sequential(
            *block(latent_dim, 128, normalize=False),
            *block(128, 256),
            *block(256, 512),
            *block(512, 1024),
            nn.Linear(1024, 1 * 28 * 28),
            nn.Tanh()
        )

    def forward(self, z):
        img = self.model(z)
        img = img.view(img.size(0), 1, 28, 28)
        return img

# %%
# 판별자(Discriminator) 클래스 정의
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()

        self.model = nn.Sequential(
            nn.Linear(1 * 28 * 28, 512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(256, 1),
            nn.Sigmoid(),
        )

    # 이미지에 대한 판별 결과를 반환
    def forward(self, img):
        flattened = img.view(img.size(0), -1)
        output = self.model(flattened)

        return output

# %%
transforms_train = transforms.Compose([
    transforms.Resize(28),
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5])
])

train_dataset = datasets.MNIST(root="./dataset", train=True, download=True, transform=transforms_train)
dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=4)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./dataset/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ./dataset/MNIST/raw/train-images-idx3-ubyte.gz to ./dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./dataset/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ./dataset/MNIST/raw/train-labels-idx1-ubyte.gz to ./dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./dataset/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ./dataset/MNIST/raw/t10k-images-idx3-ubyte.gz to ./dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./dataset/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ./dataset/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./dataset/MNIST/raw
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:566: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
# 생성자(generator)와 판별자(discriminator) 초기화
generator = Generator()
discriminator = Discriminator()

generator.cuda()
discriminator.cuda()

# 손실 함수(loss function)
adversarial_loss = nn.BCELoss()
adversarial_loss.cuda()

# 학습률(learning rate) 설정
lr = 0.0002

# 생성자와 판별자를 위한 최적화 함수
optimizer_G = torch.optim.Adam(generator.parameters(), lr=lr, betas=(0.5, 0.999))
optimizer_D = torch.optim.Adam(discriminator.parameters(), lr=lr, betas=(0.5, 0.999))

# %%
import time

n_epochs = 200 # 학습의 횟수(epoch) 설정
sample_interval = 2000 # 몇 번의 배치(batch)마다 결과를 출력할 것인지 설정
start_time = time.time()

for epoch in range(n_epochs):
    for i, (imgs, _) in enumerate(dataloader):

        # 진짜(real) 이미지와 가짜(fake) 이미지에 대한 정답 레이블 생성
        real = torch.cuda.FloatTensor(imgs.size(0), 1).fill_(1.0) # 진짜(real): 1
        fake = torch.cuda.FloatTensor(imgs.size(0), 1).fill_(0.0) # 가짜(fake): 0

        real_imgs = imgs.cuda()

        """ 생성자(generator)를 학습합니다. """
        optimizer_G.zero_grad()

        # 랜덤 노이즈(noise) 샘플링
        z = torch.normal(mean=0, std=1, size=(imgs.shape[0], latent_dim)).cuda()

        # 이미지 생성
        generated_imgs = generator(z)

        # 생성자(generator)의 손실(loss) 값 계산
        g_loss = adversarial_loss(discriminator(generated_imgs), real)

        # 생성자(generator) 업데이트
        g_loss.backward()
        optimizer_G.step()

        """ 판별자(discriminator)를 학습합니다. """
        optimizer_D.zero_grad()

        # 판별자(discriminator)의 손실(loss) 값 계산
        real_loss = adversarial_loss(discriminator(real_imgs), real)
        fake_loss = adversarial_loss(discriminator(generated_imgs.detach()), fake)
        d_loss = (real_loss + fake_loss) / 2

        # 판별자(discriminator) 업데이트
        d_loss.backward()
        optimizer_D.step()

        done = epoch * len(dataloader) + i
        if done % sample_interval == 0:
            # 생성된 이미지 중에서 25개만 선택하여 5 X 5 격자 이미지에 출력
            save_image(generated_imgs.data[:25], f"{done}.png", nrow=5, normalize=True)

    # 하나의 epoch이 끝날 때마다 로그(log) 출력
    print(f"[Epoch {epoch}/{n_epochs}] [D loss: {d_loss.item():.6f}] [G loss: {g_loss.item():.6f}] [Elapsed time: {time.time() - start_time:.2f}s]")
# Out:
# [Epoch 0/200] [D loss: 0.563192] [G loss: 0.500032] [Elapsed time: 19.05s]
# [Epoch 1/200] [D loss: 0.534399] [G loss: 0.677476] [Elapsed time: 32.68s]
# [Epoch 2/200] [D loss: 0.399083] [G loss: 1.813749] [Elapsed time: 46.35s]
# [Epoch 3/200] [D loss: 0.515247] [G loss: 2.999161] [Elapsed time: 60.19s]
# [Epoch 4/200] [D loss: 0.365569] [G loss: 1.177740] [Elapsed time: 73.78s]
# [Epoch 5/200] [D loss: 0.291155] [G loss: 1.184510] [Elapsed time: 87.61s]
# [Epoch 6/200] [D loss: 0.173032] [G loss: 1.732156] [Elapsed time: 101.38s]
# [Epoch 7/200] [D loss: 0.157079] [G loss: 1.652128] [Elapsed time: 115.20s]
# [Epoch 8/200] [D loss: 0.247204] [G loss: 2.450717] [Elapsed time: 128.84s]
# [Epoch 9/200] [D loss: 0.304900] [G loss: 1.781250] [Elapsed time: 142.62s]
# [Epoch 10/200] [D loss: 0.211862] [G loss: 1.929810] [Elapsed time: 156.40s]
# [Epoch 11/200] [D loss: 0.282318] [G loss: 2.121430] [Elapsed time: 170.23s]
# [Epoch 12/200] [D loss: 0.344326] [G loss: 1.197545] [Elapsed time: 184.18s]
# [Epoch 13/200] [D loss: 0.310569] [G loss: 1.251284] [Elapsed time: 198.07s]
# [Epoch 14/200] [D loss: 0.160545] [G loss: 2.229191] [Elapsed time: 211.85s]
# [Epoch 15/200] [D loss: 0.993347] [G loss: 9.302610] [Elapsed time: 225.53s]
# [Epoch 16/200] [D loss: 0.130214] [G loss: 2.203988] [Elapsed time: 239.41s]
# [Epoch 17/200] [D loss: 0.231978] [G loss: 1.476010] [Elapsed time: 253.23s]
# [Epoch 18/200] [D loss: 0.276894] [G loss: 1.345974] [Elapsed time: 267.04s]
# [Epoch 19/200] [D loss: 0.177313] [G loss: 2.622667] [Elapsed time: 280.71s]
# [Epoch 20/200] [D loss: 0.212215] [G loss: 1.852976] [Elapsed time: 294.46s]
# [Epoch 21/200] [D loss: 0.366942] [G loss: 3.410349] [Elapsed time: 308.24s]
# [Epoch 22/200] [D loss: 0.232387] [G loss: 1.517868] [Elapsed time: 322.00s]
# [Epoch 23/200] [D loss: 0.225540] [G loss: 1.645030] [Elapsed time: 335.99s]
# [Epoch 24/200] [D loss: 0.366855] [G loss: 2.235271] [Elapsed time: 350.57s]
# [Epoch 25/200] [D loss: 0.514221] [G loss: 0.654148] [Elapsed time: 364.32s]
# [Epoch 26/200] [D loss: 0.261605] [G loss: 2.298710] [Elapsed time: 378.30s]
# [Epoch 27/200] [D loss: 0.223440] [G loss: 1.555226] [Elapsed time: 392.34s]
# [Epoch 28/200] [D loss: 0.220939] [G loss: 1.927880] [Elapsed time: 406.08s]
# [Epoch 29/200] [D loss: 0.251065] [G loss: 1.755209] [Elapsed time: 421.41s]
# [Epoch 30/200] [D loss: 0.326860] [G loss: 1.151154] [Elapsed time: 435.28s]
# [Epoch 31/200] [D loss: 0.156422] [G loss: 3.490447] [Elapsed time: 449.20s]
# [Epoch 32/200] [D loss: 0.389531] [G loss: 3.104148] [Elapsed time: 462.98s]
# [Epoch 33/200] [D loss: 0.248962] [G loss: 1.992422] [Elapsed time: 476.71s]
# [Epoch 34/200] [D loss: 0.212136] [G loss: 2.319329] [Elapsed time: 490.70s]
# [Epoch 35/200] [D loss: 0.282852] [G loss: 1.930414] [Elapsed time: 504.91s]
# [Epoch 36/200] [D loss: 0.119767] [G loss: 2.322798] [Elapsed time: 518.74s]
# [Epoch 37/200] [D loss: 0.250271] [G loss: 2.138119] [Elapsed time: 532.56s]
# [Epoch 38/200] [D loss: 0.189237] [G loss: 2.157609] [Elapsed time: 546.54s]
# [Epoch 39/200] [D loss: 0.189675] [G loss: 1.702436] [Elapsed time: 560.18s]
# [Epoch 40/200] [D loss: 0.187870] [G loss: 1.809208] [Elapsed time: 574.11s]
# [Epoch 41/200] [D loss: 0.288903] [G loss: 1.605011] [Elapsed time: 588.01s]
# [Epoch 42/200] [D loss: 0.221731] [G loss: 1.838508] [Elapsed time: 601.81s]
# [Epoch 43/200] [D loss: 0.357106] [G loss: 4.090857] [Elapsed time: 615.52s]
# [Epoch 44/200] [D loss: 0.264414] [G loss: 2.819378] [Elapsed time: 629.25s]
# [Epoch 45/200] [D loss: 0.246864] [G loss: 1.823406] [Elapsed time: 643.03s]
# [Epoch 46/200] [D loss: 0.188481] [G loss: 2.062034] [Elapsed time: 656.92s]
# [Epoch 47/200] [D loss: 0.287731] [G loss: 1.669715] [Elapsed time: 670.78s]
# [Epoch 48/200] [D loss: 0.231084] [G loss: 1.608440] [Elapsed time: 684.64s]
# [Epoch 49/200] [D loss: 0.245291] [G loss: 1.377332] [Elapsed time: 698.52s]
# [Epoch 50/200] [D loss: 0.301012] [G loss: 4.521039] [Elapsed time: 712.24s]
# [Epoch 51/200] [D loss: 0.195511] [G loss: 1.912834] [Elapsed time: 726.05s]
# [Epoch 52/200] [D loss: 0.218732] [G loss: 3.618000] [Elapsed time: 739.80s]
# [Epoch 53/200] [D loss: 0.172518] [G loss: 2.038317] [Elapsed time: 753.48s]
# [Epoch 54/200] [D loss: 0.245129] [G loss: 1.819610] [Elapsed time: 767.38s]
# [Epoch 55/200] [D loss: 0.223273] [G loss: 2.573568] [Elapsed time: 781.07s]
# [Epoch 56/200] [D loss: 0.150530] [G loss: 3.365246] [Elapsed time: 794.91s]
# [Epoch 57/200] [D loss: 0.199082] [G loss: 2.563440] [Elapsed time: 808.97s]
# [Epoch 58/200] [D loss: 0.158011] [G loss: 2.480103] [Elapsed time: 823.12s]
# [Epoch 59/200] [D loss: 0.168842] [G loss: 2.271453] [Elapsed time: 837.02s]
# [Epoch 60/200] [D loss: 0.223641] [G loss: 1.949468] [Elapsed time: 850.99s]
# [Epoch 61/200] [D loss: 0.282747] [G loss: 1.474203] [Elapsed time: 864.80s]
# [Epoch 62/200] [D loss: 0.204702] [G loss: 1.543786] [Elapsed time: 878.36s]
# [Epoch 63/200] [D loss: 0.319430] [G loss: 2.001582] [Elapsed time: 892.05s]
# [Epoch 64/200] [D loss: 0.263799] [G loss: 1.825834] [Elapsed time: 905.83s]
# [Epoch 65/200] [D loss: 0.279932] [G loss: 1.781979] [Elapsed time: 919.52s]
# [Epoch 66/200] [D loss: 0.341653] [G loss: 1.702012] [Elapsed time: 933.07s]
# [Epoch 67/200] [D loss: 0.267449] [G loss: 1.648906] [Elapsed time: 946.74s]
# [Epoch 68/200] [D loss: 0.324147] [G loss: 2.524620] [Elapsed time: 960.36s]
# [Epoch 69/200] [D loss: 0.323134] [G loss: 1.315527] [Elapsed time: 974.10s]
# [Epoch 70/200] [D loss: 0.256209] [G loss: 1.867573] [Elapsed time: 987.82s]
# [Epoch 71/200] [D loss: 0.266651] [G loss: 1.583369] [Elapsed time: 1001.62s]
# [Epoch 72/200] [D loss: 0.344325] [G loss: 1.601980] [Elapsed time: 1015.30s]
# [Epoch 73/200] [D loss: 0.307602] [G loss: 1.455551] [Elapsed time: 1029.10s]
# [Epoch 74/200] [D loss: 0.273738] [G loss: 1.675510] [Elapsed time: 1042.63s]
# [Epoch 75/200] [D loss: 0.223476] [G loss: 1.902102] [Elapsed time: 1056.19s]
# [Epoch 76/200] [D loss: 0.315401] [G loss: 2.498387] [Elapsed time: 1069.85s]
# [Epoch 77/200] [D loss: 0.469130] [G loss: 0.878265] [Elapsed time: 1083.46s]
# [Epoch 78/200] [D loss: 0.278411] [G loss: 1.808188] [Elapsed time: 1097.27s]
# [Epoch 79/200] [D loss: 0.270717] [G loss: 2.506182] [Elapsed time: 1110.94s]
# [Epoch 80/200] [D loss: 0.280355] [G loss: 1.703045] [Elapsed time: 1124.84s]
# [Epoch 81/200] [D loss: 0.273670] [G loss: 3.525420] [Elapsed time: 1138.67s]
# [Epoch 82/200] [D loss: 0.213019] [G loss: 2.069304] [Elapsed time: 1152.38s]
# [Epoch 83/200] [D loss: 0.248691] [G loss: 2.592591] [Elapsed time: 1166.06s]
# [Epoch 84/200] [D loss: 0.754554] [G loss: 6.001485] [Elapsed time: 1179.64s]
# [Epoch 85/200] [D loss: 0.318734] [G loss: 3.012393] [Elapsed time: 1193.32s]
# [Epoch 86/200] [D loss: 0.244154] [G loss: 1.826085] [Elapsed time: 1207.56s]
# [Epoch 87/200] [D loss: 0.274233] [G loss: 1.809937] [Elapsed time: 1221.71s]
# [Epoch 88/200] [D loss: 0.239934] [G loss: 2.036541] [Elapsed time: 1235.77s]
# [Epoch 89/200] [D loss: 0.290615] [G loss: 1.730893] [Elapsed time: 1249.72s]
# [Epoch 90/200] [D loss: 0.260990] [G loss: 1.768470] [Elapsed time: 1263.62s]
# [Epoch 91/200] [D loss: 0.269943] [G loss: 2.301803] [Elapsed time: 1277.51s]
# [Epoch 92/200] [D loss: 0.356612] [G loss: 1.324641] [Elapsed time: 1291.54s]
# [Epoch 93/200] [D loss: 0.283332] [G loss: 1.696029] [Elapsed time: 1305.72s]
# [Epoch 94/200] [D loss: 0.333712] [G loss: 2.784065] [Elapsed time: 1319.80s]
# [Epoch 95/200] [D loss: 0.244203] [G loss: 2.786095] [Elapsed time: 1333.84s]
# [Epoch 96/200] [D loss: 0.339802] [G loss: 1.426429] [Elapsed time: 1347.77s]
# [Epoch 97/200] [D loss: 0.262782] [G loss: 2.267395] [Elapsed time: 1361.74s]
# [Epoch 98/200] [D loss: 0.242925] [G loss: 2.083907] [Elapsed time: 1375.70s]
# [Epoch 99/200] [D loss: 0.241673] [G loss: 2.215820] [Elapsed time: 1389.84s]
# [Epoch 100/200] [D loss: 0.366175] [G loss: 3.579837] [Elapsed time: 1403.85s]
# [Epoch 101/200] [D loss: 0.237653] [G loss: 2.148299] [Elapsed time: 1417.75s]
# [Epoch 102/200] [D loss: 0.282405] [G loss: 2.615947] [Elapsed time: 1431.86s]
# [Epoch 103/200] [D loss: 0.235586] [G loss: 1.799667] [Elapsed time: 1446.01s]
# [Epoch 104/200] [D loss: 0.364102] [G loss: 1.390306] [Elapsed time: 1459.97s]
# [Epoch 105/200] [D loss: 0.306386] [G loss: 2.414075] [Elapsed time: 1473.92s]
# [Epoch 106/200] [D loss: 0.226956] [G loss: 2.402822] [Elapsed time: 1487.98s]
# [Epoch 107/200] [D loss: 0.282421] [G loss: 2.651369] [Elapsed time: 1501.84s]
# [Epoch 108/200] [D loss: 0.184566] [G loss: 1.850787] [Elapsed time: 1515.94s]
# [Epoch 109/200] [D loss: 0.292856] [G loss: 2.013606] [Elapsed time: 1529.99s]
# [Epoch 110/200] [D loss: 0.186226] [G loss: 2.422571] [Elapsed time: 1544.06s]
# [Epoch 111/200] [D loss: 0.290997] [G loss: 2.079521] [Elapsed time: 1558.29s]
# [Epoch 112/200] [D loss: 0.257279] [G loss: 2.700657] [Elapsed time: 1572.18s]
# [Epoch 113/200] [D loss: 0.383230] [G loss: 2.898330] [Elapsed time: 1586.16s]
# [Epoch 114/200] [D loss: 0.408457] [G loss: 4.320498] [Elapsed time: 1600.14s]
# [Epoch 115/200] [D loss: 0.215554] [G loss: 2.609629] [Elapsed time: 1614.13s]
# [Epoch 116/200] [D loss: 0.271893] [G loss: 1.769122] [Elapsed time: 1628.20s]
# [Epoch 117/200] [D loss: 0.263680] [G loss: 1.465870] [Elapsed time: 1642.17s]
# [Epoch 118/200] [D loss: 0.325866] [G loss: 1.977328] [Elapsed time: 1655.92s]
# [Epoch 119/200] [D loss: 0.283873] [G loss: 2.326987] [Elapsed time: 1670.21s]
# [Epoch 120/200] [D loss: 0.296753] [G loss: 1.818030] [Elapsed time: 1684.07s]
# [Epoch 121/200] [D loss: 0.186413] [G loss: 1.909998] [Elapsed time: 1697.91s]
# [Epoch 122/200] [D loss: 0.241199] [G loss: 2.082759] [Elapsed time: 1711.85s]
# [Epoch 123/200] [D loss: 0.338103] [G loss: 1.285320] [Elapsed time: 1725.46s]
# [Epoch 124/200] [D loss: 0.295303] [G loss: 1.680918] [Elapsed time: 1739.17s]
# [Epoch 125/200] [D loss: 0.301003] [G loss: 2.992107] [Elapsed time: 1752.89s]
# [Epoch 126/200] [D loss: 0.270127] [G loss: 1.971159] [Elapsed time: 1766.41s]
# [Epoch 127/200] [D loss: 0.293168] [G loss: 3.121809] [Elapsed time: 1779.92s]
# [Epoch 128/200] [D loss: 0.290776] [G loss: 1.948826] [Elapsed time: 1793.51s]
# [Epoch 129/200] [D loss: 0.264551] [G loss: 2.308292] [Elapsed time: 1807.09s]
# [Epoch 130/200] [D loss: 0.360702] [G loss: 3.472733] [Elapsed time: 1820.64s]
# [Epoch 131/200] [D loss: 0.267806] [G loss: 2.559402] [Elapsed time: 1834.15s]
# [Epoch 132/200] [D loss: 0.318608] [G loss: 2.980321] [Elapsed time: 1847.61s]
# [Epoch 133/200] [D loss: 0.314609] [G loss: 1.589889] [Elapsed time: 1861.15s]
# [Epoch 134/200] [D loss: 0.221629] [G loss: 1.808556] [Elapsed time: 1874.55s]
# [Epoch 135/200] [D loss: 0.213049] [G loss: 2.073272] [Elapsed time: 1887.99s]
# [Epoch 136/200] [D loss: 0.226746] [G loss: 1.997929] [Elapsed time: 1901.51s]
# [Epoch 137/200] [D loss: 0.272713] [G loss: 2.517511] [Elapsed time: 1915.04s]
# [Epoch 138/200] [D loss: 0.337003] [G loss: 1.808799] [Elapsed time: 1928.58s]
# [Epoch 139/200] [D loss: 0.192300] [G loss: 2.250715] [Elapsed time: 1942.05s]
# [Epoch 140/200] [D loss: 0.250751] [G loss: 2.281250] [Elapsed time: 1955.68s]
# [Epoch 141/200] [D loss: 0.248871] [G loss: 1.603257] [Elapsed time: 1969.21s]
# [Epoch 142/200] [D loss: 0.290387] [G loss: 2.483413] [Elapsed time: 1982.75s]
# [Epoch 143/200] [D loss: 0.293339] [G loss: 3.296183] [Elapsed time: 1996.30s]
# [Epoch 144/200] [D loss: 0.216918] [G loss: 1.960842] [Elapsed time: 2009.81s]
# [Epoch 145/200] [D loss: 0.340817] [G loss: 3.338311] [Elapsed time: 2023.24s]
# [Epoch 146/200] [D loss: 0.259089] [G loss: 2.165416] [Elapsed time: 2036.93s]
# [Epoch 147/200] [D loss: 0.308331] [G loss: 1.969124] [Elapsed time: 2050.58s]
# [Epoch 148/200] [D loss: 0.286561] [G loss: 2.108875] [Elapsed time: 2064.14s]
# [Epoch 149/200] [D loss: 0.289594] [G loss: 2.457278] [Elapsed time: 2077.73s]
# [Epoch 150/200] [D loss: 0.303940] [G loss: 2.995729] [Elapsed time: 2091.29s]
# [Epoch 151/200] [D loss: 0.212086] [G loss: 2.312895] [Elapsed time: 2104.90s]
# [Epoch 152/200] [D loss: 0.237543] [G loss: 2.014379] [Elapsed time: 2118.45s]
# [Epoch 153/200] [D loss: 0.263995] [G loss: 2.141730] [Elapsed time: 2132.00s]
# [Epoch 154/200] [D loss: 0.294560] [G loss: 2.259525] [Elapsed time: 2145.41s]
# [Epoch 155/200] [D loss: 0.309841] [G loss: 2.532449] [Elapsed time: 2158.96s]
# [Epoch 156/200] [D loss: 0.280950] [G loss: 2.249571] [Elapsed time: 2172.69s]
# [Epoch 157/200] [D loss: 0.302951] [G loss: 2.255236] [Elapsed time: 2186.23s]
# [Epoch 158/200] [D loss: 0.222810] [G loss: 2.378823] [Elapsed time: 2199.93s]
# [Epoch 159/200] [D loss: 0.208306] [G loss: 2.490371] [Elapsed time: 2213.52s]
# [Epoch 160/200] [D loss: 0.294672] [G loss: 2.749410] [Elapsed time: 2227.14s]
# [Epoch 161/200] [D loss: 0.304871] [G loss: 1.519981] [Elapsed time: 2240.66s]
# [Epoch 162/200] [D loss: 0.350272] [G loss: 2.473851] [Elapsed time: 2254.35s]
# [Epoch 163/200] [D loss: 0.241846] [G loss: 2.630954] [Elapsed time: 2267.99s]
# [Epoch 164/200] [D loss: 0.324654] [G loss: 1.625128] [Elapsed time: 2281.54s]
# [Epoch 165/200] [D loss: 0.253338] [G loss: 1.925055] [Elapsed time: 2295.15s]
# [Epoch 166/200] [D loss: 0.251586] [G loss: 2.397178] [Elapsed time: 2308.60s]
# [Epoch 167/200] [D loss: 0.231458] [G loss: 1.996558] [Elapsed time: 2322.15s]
# [Epoch 168/200] [D loss: 0.311254] [G loss: 2.237909] [Elapsed time: 2335.64s]
# [Epoch 169/200] [D loss: 0.295141] [G loss: 2.117727] [Elapsed time: 2349.42s]
# [Epoch 170/200] [D loss: 0.319817] [G loss: 2.118154] [Elapsed time: 2363.08s]
# [Epoch 171/200] [D loss: 0.426238] [G loss: 3.856899] [Elapsed time: 2376.46s]
# [Epoch 172/200] [D loss: 0.197045] [G loss: 2.857005] [Elapsed time: 2390.07s]
# [Epoch 173/200] [D loss: 0.270420] [G loss: 1.719267] [Elapsed time: 2403.39s]
# [Epoch 174/200] [D loss: 0.272506] [G loss: 1.833910] [Elapsed time: 2416.86s]
# [Epoch 175/200] [D loss: 0.339595] [G loss: 1.825435] [Elapsed time: 2430.38s]
# [Epoch 176/200] [D loss: 0.196544] [G loss: 3.094922] [Elapsed time: 2443.88s]
# [Epoch 177/200] [D loss: 0.285637] [G loss: 2.223213] [Elapsed time: 2457.45s]
# [Epoch 178/200] [D loss: 0.289000] [G loss: 2.365781] [Elapsed time: 2471.10s]
# [Epoch 179/200] [D loss: 0.264999] [G loss: 1.879457] [Elapsed time: 2484.53s]
# [Epoch 180/200] [D loss: 0.329072] [G loss: 2.955553] [Elapsed time: 2497.97s]
# [Epoch 181/200] [D loss: 0.246226] [G loss: 1.776024] [Elapsed time: 2511.48s]
# [Epoch 182/200] [D loss: 0.200907] [G loss: 2.191538] [Elapsed time: 2524.96s]
# [Epoch 183/200] [D loss: 0.217264] [G loss: 2.107457] [Elapsed time: 2538.53s]
# [Epoch 184/200] [D loss: 0.267957] [G loss: 3.138098] [Elapsed time: 2551.71s]
# [Epoch 185/200] [D loss: 0.202290] [G loss: 2.063213] [Elapsed time: 2565.12s]
# [Epoch 186/200] [D loss: 0.340988] [G loss: 1.308912] [Elapsed time: 2578.69s]
# [Epoch 187/200] [D loss: 0.253858] [G loss: 2.415555] [Elapsed time: 2592.14s]
# [Epoch 188/200] [D loss: 0.298409] [G loss: 3.399921] [Elapsed time: 2605.72s]
# [Epoch 189/200] [D loss: 0.215089] [G loss: 1.976238] [Elapsed time: 2619.07s]
# [Epoch 190/200] [D loss: 0.293523] [G loss: 1.767417] [Elapsed time: 2632.72s]
# [Epoch 191/200] [D loss: 0.236874] [G loss: 1.627643] [Elapsed time: 2646.17s]
# [Epoch 192/200] [D loss: 0.215193] [G loss: 1.944929] [Elapsed time: 2659.64s]
# [Epoch 193/200] [D loss: 0.248159] [G loss: 1.916963] [Elapsed time: 2673.26s]
# [Epoch 194/200] [D loss: 0.347748] [G loss: 1.139376] [Elapsed time: 2686.96s]
# [Epoch 195/200] [D loss: 0.226292] [G loss: 2.581308] [Elapsed time: 2700.30s]
# [Epoch 196/200] [D loss: 0.292006] [G loss: 2.243761] [Elapsed time: 2713.88s]
# [Epoch 197/200] [D loss: 0.236717] [G loss: 2.382392] [Elapsed time: 2727.34s]
# [Epoch 198/200] [D loss: 0.192573] [G loss: 2.493350] [Elapsed time: 2740.85s]
# [Epoch 199/200] [D loss: 0.277831] [G loss: 2.770165] [Elapsed time: 2754.52s]

# %%
from IPython.display import Image

Image('92000.png')
