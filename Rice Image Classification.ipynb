# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os

# %matplotlib inline

# %%
# !pip install split-folders

import splitfolders
splitfolders.ratio('/content/drive/MyDrive/machine learning projects/training set/Rice_Image_Dataset', output="output", seed=1337, ratio=(.8, 0.1,0.1))
# Out:
# Requirement already satisfied: split-folders in /usr/local/lib/python3.7/dist-packages (0.5.1)
# Copying files: 75000 files [52:29, 23.82 files/s]

# %%
BATCH = 64
IMG_WIDTH = 96
IMG_HEIGHT = 96

# %%
train_loader = tf.keras.preprocessing.image_dataset_from_directory(
"./output/train",
seed=123,
image_size=(IMG_HEIGHT, IMG_WIDTH),
batch_size=BATCH
)

test_loader = tf.keras.preprocessing.image_dataset_from_directory(
"./output/test",
seed=123,
image_size=(IMG_HEIGHT, IMG_WIDTH),
batch_size=BATCH
)

validation_loader = tf.keras.preprocessing.image_dataset_from_directory(
"./output/val",
seed=123,
image_size=(IMG_HEIGHT, IMG_WIDTH),
batch_size=BATCH
)
# Out:
# Found 60000 files belonging to 5 classes.
# Found 7500 files belonging to 5 classes.
# Found 7500 files belonging to 5 classes.

# %%
class_names = train_loader.class_names
print(class_names)
# Out:
# ['Arborio', 'Basmati', 'Ipsala', 'Jasmine', 'Karacadag']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_loader.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_loader.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
test_dataset = test_loader.cache().prefetch(buffer_size=AUTOTUNE)
val_dataset = validation_loader.cache().prefetch(buffer_size=AUTOTUNE)

# %%
data_augmentation = tf.keras.Sequential(
  [
    tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(IMG_HEIGHT, 
                                                              IMG_WIDTH,
                                                              3)),
    tf.keras.layers.experimental.preprocessing.RandomRotation(0.1),
    tf.keras.layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

# %%
model = tf.keras.models.Sequential([
    data_augmentation,
    tf.keras.layers.experimental.preprocessing.Rescaling(1./255),
    tf.keras.layers.Conv2D(16, 3, padding='same', activation='relu'),
    tf.keras.layers.MaxPooling2D(),
  
    tf.keras.layers.Conv2D(32, 3, padding='same', activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    
    tf.keras.layers.Conv2D(64, 3, padding='same', activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    
    tf.keras.layers.Conv2D(128, 3, padding='same', activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(len(class_names))
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 96, 96, 3)         0
#
#  rescaling (Rescaling)       (None, 96, 96, 3)         0
#
#  conv2d (Conv2D)             (None, 96, 96, 16)        448
#
#  max_pooling2d (MaxPooling2D  (None, 48, 48, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 24, 24, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 128)       73856
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 128)               589952
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 688,037
# Trainable params: 688,037
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 50
history = model.fit(
  train_dataset,
  validation_data=val_dataset,
  epochs=epochs
)
# Out:
# Epoch 1/50
# 938/938 [==============================] - 732s 780ms/step - loss: 0.1509 - accuracy: 0.9479 - val_loss: 0.1005 - val_accuracy: 0.9649
# Epoch 2/50
# 938/938 [==============================] - 711s 758ms/step - loss: 0.0930 - accuracy: 0.9692 - val_loss: 0.0794 - val_accuracy: 0.9724
# Epoch 3/50
# 938/938 [==============================] - 709s 756ms/step - loss: 0.0489 - accuracy: 0.9843 - val_loss: 0.1464 - val_accuracy: 0.9471
# Epoch 4/50
# 938/938 [==============================] - 720s 767ms/step - loss: 0.0360 - accuracy: 0.9883 - val_loss: 0.0380 - val_accuracy: 0.9880
# Epoch 5/50
# 938/938 [==============================] - 707s 753ms/step - loss: 0.0283 - accuracy: 0.9912 - val_loss: 0.1024 - val_accuracy: 0.9635
# Epoch 6/50
# 938/938 [==============================] - 709s 756ms/step - loss: 0.0221 - accuracy: 0.9927 - val_loss: 0.0905 - val_accuracy: 0.9677
# Epoch 7/50
# 938/938 [==============================] - 718s 766ms/step - loss: 0.0228 - accuracy: 0.9930 - val_loss: 0.1406 - val_accuracy: 0.9467
# Epoch 8/50
# 938/938 [==============================] - 715s 762ms/step - loss: 0.0200 - accuracy: 0.9938 - val_loss: 0.0712 - val_accuracy: 0.9731
# Epoch 9/50
# 938/938 [==============================] - 722s 770ms/step - loss: 0.0174 - accuracy: 0.9946 - val_loss: 0.0162 - val_accuracy: 0.9948
# Epoch 10/50
# 938/938 [==============================] - 730s 779ms/step - loss: 0.0177 - accuracy: 0.9942 - val_loss: 0.0139 - val_accuracy: 0.9960
# Epoch 11/50
# 938/938 [==============================] - 714s 762ms/step - loss: 0.0171 - accuracy: 0.9948 - val_loss: 0.0091 - val_accuracy: 0.9972
# Epoch 12/50
# 938/938 [==============================] - 708s 754ms/step - loss: 0.0157 - accuracy: 0.9952 - val_loss: 0.0220 - val_accuracy: 0.9932
# Epoch 13/50
# 938/938 [==============================] - 725s 773ms/step - loss: 0.0173 - accuracy: 0.9948 - val_loss: 0.0181 - val_accuracy: 0.9943
# Epoch 14/50
# 938/938 [==============================] - 721s 768ms/step - loss: 0.0167 - accuracy: 0.9949 - val_loss: 0.0112 - val_accuracy: 0.9957
# Epoch 15/50
# 938/938 [==============================] - 711s 758ms/step - loss: 0.0161 - accuracy: 0.9952 - val_loss: 0.0202 - val_accuracy: 0.9931
# Epoch 16/50
# 938/938 [==============================] - 718s 766ms/step - loss: 0.0158 - accuracy: 0.9954 - val_loss: 0.0248 - val_accuracy: 0.9921
# Epoch 17/50
# 938/938 [==============================] - 712s 759ms/step - loss: 0.0149 - accuracy: 0.9955 - val_loss: 0.0143 - val_accuracy: 0.9956
# Epoch 18/50
# 938/938 [==============================] - 714s 761ms/step - loss: 0.0148 - accuracy: 0.9958 - val_loss: 0.0098 - val_accuracy: 0.9969
# Epoch 19/50
# 938/938 [==============================] - 713s 760ms/step - loss: 0.0147 - accuracy: 0.9955 - val_loss: 0.0240 - val_accuracy: 0.9923
# Epoch 20/50
# 938/938 [==============================] - 707s 754ms/step - loss: 0.0130 - accuracy: 0.9964 - val_loss: 0.0105 - val_accuracy: 0.9960
# Epoch 21/50
# 938/938 [==============================] - 701s 748ms/step - loss: 0.0132 - accuracy: 0.9959 - val_loss: 0.0280 - val_accuracy: 0.9923
# Epoch 22/50
# 938/938 [==============================] - 696s 742ms/step - loss: 0.0135 - accuracy: 0.9960 - val_loss: 0.0549 - val_accuracy: 0.9827
# Epoch 23/50
# 938/938 [==============================] - 697s 743ms/step - loss: 0.0128 - accuracy: 0.9962 - val_loss: 0.0132 - val_accuracy: 0.9959
# Epoch 24/50
# 938/938 [==============================] - 696s 742ms/step - loss: 0.0119 - accuracy: 0.9965 - val_loss: 0.0278 - val_accuracy: 0.9921
# Epoch 25/50
# 938/938 [==============================] - 699s 746ms/step - loss: 0.0139 - accuracy: 0.9958 - val_loss: 0.0171 - val_accuracy: 0.9948
# Epoch 26/50
# 938/938 [==============================] - 700s 747ms/step - loss: 0.0125 - accuracy: 0.9964 - val_loss: 0.0610 - val_accuracy: 0.9799
# Epoch 27/50
# 938/938 [==============================] - 691s 736ms/step - loss: 0.0130 - accuracy: 0.9959 - val_loss: 0.0185 - val_accuracy: 0.9933
# Epoch 28/50
# 938/938 [==============================] - 694s 740ms/step - loss: 0.0124 - accuracy: 0.9964 - val_loss: 0.0183 - val_accuracy: 0.9939
# Epoch 29/50
# 938/938 [==============================] - 694s 740ms/step - loss: 0.0124 - accuracy: 0.9963 - val_loss: 0.0247 - val_accuracy: 0.9921
# Epoch 30/50
# 938/938 [==============================] - 695s 741ms/step - loss: 0.0122 - accuracy: 0.9962 - val_loss: 0.0224 - val_accuracy: 0.9929
# Epoch 31/50
# 938/938 [==============================] - 693s 739ms/step - loss: 0.0117 - accuracy: 0.9969 - val_loss: 0.0150 - val_accuracy: 0.9960
# Epoch 32/50
# 938/938 [==============================] - 689s 734ms/step - loss: 0.0105 - accuracy: 0.9968 - val_loss: 0.0357 - val_accuracy: 0.9908
# Epoch 33/50
# 938/938 [==============================] - 693s 738ms/step - loss: 0.0110 - accuracy: 0.9968 - val_loss: 0.0152 - val_accuracy: 0.9957
# Epoch 34/50
# 938/938 [==============================] - 694s 740ms/step - loss: 0.0113 - accuracy: 0.9966 - val_loss: 0.0374 - val_accuracy: 0.9891
# Epoch 35/50
# 938/938 [==============================] - 690s 735ms/step - loss: 0.0110 - accuracy: 0.9966 - val_loss: 0.0211 - val_accuracy: 0.9940
# Epoch 36/50
# 938/938 [==============================] - 695s 741ms/step - loss: 0.0106 - accuracy: 0.9973 - val_loss: 0.0121 - val_accuracy: 0.9960
# Epoch 37/50
# 938/938 [==============================] - 688s 734ms/step - loss: 0.0137 - accuracy: 0.9962 - val_loss: 0.0123 - val_accuracy: 0.9957
# Epoch 38/50
# 938/938 [==============================] - 694s 740ms/step - loss: 0.0100 - accuracy: 0.9970 - val_loss: 0.0338 - val_accuracy: 0.9892
# Epoch 39/50
# 938/938 [==============================] - 691s 737ms/step - loss: 0.0103 - accuracy: 0.9971 - val_loss: 0.0069 - val_accuracy: 0.9972
# Epoch 40/50
# 938/938 [==============================] - 687s 732ms/step - loss: 0.0103 - accuracy: 0.9973 - val_loss: 0.0127 - val_accuracy: 0.9957
# Epoch 41/50
# 938/938 [==============================] - 691s 737ms/step - loss: 0.0112 - accuracy: 0.9966 - val_loss: 0.0094 - val_accuracy: 0.9971
# Epoch 42/50
# 938/938 [==============================] - 691s 737ms/step - loss: 0.0095 - accuracy: 0.9974 - val_loss: 0.0064 - val_accuracy: 0.9981
# Epoch 43/50
# 938/938 [==============================] - 696s 743ms/step - loss: 0.0086 - accuracy: 0.9974 - val_loss: 0.0146 - val_accuracy: 0.9945
# Epoch 44/50
# 938/938 [==============================] - 704s 751ms/step - loss: 0.0098 - accuracy: 0.9970 - val_loss: 0.0132 - val_accuracy: 0.9949
# Epoch 45/50
# 938/938 [==============================] - 703s 749ms/step - loss: 0.0093 - accuracy: 0.9975 - val_loss: 0.0182 - val_accuracy: 0.9952
# Epoch 46/50
# 938/938 [==============================] - 698s 744ms/step - loss: 0.0113 - accuracy: 0.9965 - val_loss: 0.0176 - val_accuracy: 0.9951
# Epoch 47/50
# 938/938 [==============================] - 702s 749ms/step - loss: 0.0122 - accuracy: 0.9963 - val_loss: 0.0091 - val_accuracy: 0.9969
# Epoch 48/50
# 938/938 [==============================] - 707s 754ms/step - loss: 0.0089 - accuracy: 0.9975 - val_loss: 0.0184 - val_accuracy: 0.9939
# Epoch 49/50
# 938/938 [==============================] - 711s 758ms/step - loss: 0.0099 - accuracy: 0.9973 - val_loss: 0.0147 - val_accuracy: 0.9961
# Epoch 50/50
# 938/938 [==============================] - 710s 756ms/step - loss: 0.0094 - accuracy: 0.9970 - val_loss: 0.0113 - val_accuracy: 0.9964

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
loss, accuracy = model.evaluate(test_dataset)
# Out:
# 118/118 [==============================] - 30s 248ms/step - loss: 0.0125 - accuracy: 0.9968

# %%
plt.figure(figsize=(10, 10))
for images, labels in test_loader.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        predictions = model.predict(tf.expand_dims(images[i], 0))
        score = tf.nn.softmax(predictions[0])
        plt.ylabel("Predicted: "+class_names[np.argmax(score)])
        plt.title("Actual: "+class_names[labels[i]])
        plt.gca().axes.yaxis.set_ticklabels([])        
        plt.gca().axes.xaxis.set_ticklabels([])
